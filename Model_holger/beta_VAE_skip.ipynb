# %% [markdown]
# # Generative Medical Image Segmentation

# %%
# --- Import Libraries ---
import os
import torch.nn.functional as F
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyro
import pyro.distributions as dist
import seaborn as sns
import torch
from PIL import Image
from sklearn.model_selection import train_test_split
from pyro.infer import SVI, JitTrace_ELBO, Trace_ELBO, Predictive
from pyro.optim import Adam
from torch import nn
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

# Define device
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"


# --- Set Plot Style ---
sns.set_style("dark")
plt.style.use("dark_background")

# --- Define Parameters ---
BATCH_SIZE = 64
IMG_SIZE = 64
NUM_WORKERS = 0

# %%
# --- LOAD DATA ---
data_path = "data/" # Path to the data folder

# Define image paths
data = []

for dir_ in os.listdir(data_path):
    dir_path = os.path.join(data_path, dir_)
    if os.path.isdir(dir_path):
        for filename in os.listdir(dir_path):
            img_path = os.path.join(dir_path, filename)
            data.append([dir_, img_path])
    else:
        print(f"This is not an image folder: {dir_path}")
# Out:
# This is not an image folder: data/.DS_Store
# This is not an image folder: data/data.csv
# This is not an image folder: data/README.md

# %%
# --- Create image and mask paths ---
df = pd.DataFrame(data, columns=["dir_name", "image_path"])

df_imgs = df[~df["image_path"].str.contains("mask")]
df_masks = df[df["image_path"].str.contains("mask")]

imgs = sorted(df_imgs["image_path"].values, key = lambda x: int(x.split("_")[-1].split(".")[0]))
masks = sorted(df_masks["image_path"].values, key = lambda x: int(x.split("_")[-2]))

# --- Create final dataframe ---
df_final = pd.DataFrame()
df_final["image_path"] = imgs
df_final["mask_path"] = masks

# Create new column for diagnosis
def diagnosis(mask_path):
    """
    Function to determine the diagnosis based on the mask.
    If the mask is empty (all zeros), the diagnosis is 0.
    If the mask contains any non-zero values, the diagnosis is 1.
    """
    
    if np.max(cv2.imread(mask_path)) == 0:
        return 0
    else:
        return 1
    
df_final["diagnosis"] = df_final["mask_path"].apply(diagnosis)

# %%
# --- Define Dataset ---
class MRIDataset(Dataset):
    def __init__(self, df, img_transform=None, mask_transform=None):
        self.df = df
        self.img_transform = img_transform
        self.mask_transform = mask_transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.iloc[idx]["image_path"]
        mask_path = self.df.iloc[idx]["mask_path"]

        # Load image in grayscale
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # shape (H, W)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # shape (H, W)

        # Convert to PIL Image (mode 'L' = 8-bit pixels, black and white)
        image = Image.fromarray(image).convert("L")
        mask = Image.fromarray(mask).convert("L")

        # Apply transforms
        if self.img_transform:
            image = self.img_transform(image)
        if self.mask_transform:
            mask = self.mask_transform(mask)

        return image, mask
    
img_transforms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor()  # Converts to shape [1, H, W] automatically for grayscale
])

mask_transforms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor()  # Also gives [1, H, W], useful for segmentation
])

# %% [markdown]
# ### Split Data into Training, Test Sets

# %%
# Split the data into training and validation sets
train_df, test_df = train_test_split(df_final, test_size=0.1, random_state=42, stratify=df_final["diagnosis"])

# Create datasets
train_dataset = MRIDataset(train_df, img_transform=img_transforms, mask_transform=mask_transforms)
test_dataset = MRIDataset(test_df, img_transform=img_transforms, mask_transform=mask_transforms)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of test samples: {len(test_dataset)}")

print(train_dataset[0][0].shape)
# Out:
# Number of training samples: 3536
# Number of test samples: 393
# torch.Size([1, 64, 64])

# %% [markdown]
# ### Vizualize MRI images and Masks

# %%
# --- Visualize some images and masks ---
def visualize_data(loader, num_images=5):
    images, masks = next(iter(loader))
    images = images.numpy()
    masks = masks.numpy()

    fig, axes = plt.subplots(2, num_images, figsize=(10, 20))
    for i in range(num_images):
        axes[0, i].imshow(images[i].transpose(1, 2, 0), cmap='gray')
        axes[0, i].axis("off")
        axes[1, i].imshow(masks[i].transpose(1, 2, 0), cmap='gray')
        axes[1, i].axis("off")
    plt.subplots_adjust(hspace=-0.9)
    plt.show()

visualize_data(train_loader)

# %% [markdown]
# ### Define Model

# %%
# --- Define Encoder ---
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim, input_dim = IMG_SIZE*IMG_SIZE*3):

        super().__init__()
        import numpy as np
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.latent = z_dim
        hid_channels = 32
        self.img_size = (1, 64, 64)
        kernel = 4
        self.reshape = (hid_channels, kernel, kernel)
        in_chan = self.img_size[0]

        cnn_kwargs = dict(stride=2, padding=1)
        self.conv1 = nn.Conv2d(in_chan, hid_channels, kernel, **cnn_kwargs)
        self.conv2 = nn.Conv2d(hid_channels, hid_channels, kernel, **cnn_kwargs)
        self.conv3 = nn.Conv2d(hid_channels, hid_channels, kernel, **cnn_kwargs)

        if self.img_size[1] == self.img_size[2] == 64:
            self.conv_64 = nn.Conv2d(hid_channels, hid_channels, kernel, **cnn_kwargs)


        # setup the three linear transformations used
        self.fc1 = nn.Linear(np.prod(self.reshape), self.hidden_dim)
        self.fc2 = nn.Linear(self.hidden_dim, self.hidden_dim)

        self.mean_var = nn.Linear(self.hidden_dim, self.latent * 2)


    def forward(self, x):
  # Convolutional layers with ReLu activations
        batch_size = x.size(0)
        e1 = torch.relu(self.conv1(x))
        e2 = torch.relu(self.conv2(e1))
        e3 = torch.relu(self.conv3(e2))
        if self.img_size[1] == self.img_size[2] == 64:
            e4 = torch.relu(self.conv_64(e3))
        #x = F.leaky_relu(self.conv1(x))
        #x = F.leaky_relu(self.conv2(x))
        #x = F.leaky_relu(self.conv3(x))
        #if self.img_size[1] == self.img_size[2] == 64:
        #    x = F.leaky_relu(self.conv_64(x))
        # Fully connected layers with ReLu activations
        x = e4.view((batch_size, -1))
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        #x = x.view((batch_size, -1))
        #x = F.leaky_relu(self.fc1(x))
        #x = F.leaky_relu(self.fc2(x))

        # Fully connected layer for log variance and mean
        # Log std-dev in paper (bear in mind)
        mu_logvar = self.mean_var(x)
        mu, logvar = mu_logvar.view(-1, self.latent, 2).unbind(-1)

        return mu, logvar, [e1, e2, e3]
    
# --- Define Decoder ---
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim, output_dim):
        super().__init__()
        import numpy as np
        self.z_dim = z_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.img_size = (1, 64, 64)
        hid_channels = 32
        kernel = 4
        self.reshape = (hid_channels, kernel, kernel)
        in_chan = self.img_size[0]

        # Linear layers
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, np.prod(self.reshape))

        # ConvTranspose2d (adjust input channels to match skip connection concatenation)
        cnn_kwargs = dict(stride=2, padding=1)

        self.up1 = nn.ConvTranspose2d(hid_channels, hid_channels, kernel, **cnn_kwargs)         # No skip
        self.up2 = nn.ConvTranspose2d(hid_channels, hid_channels, kernel, **cnn_kwargs)  # + e3
        self.up3 = nn.ConvTranspose2d(hid_channels, hid_channels, kernel, **cnn_kwargs)  # + e2
        self.up4 = nn.ConvTranspose2d(hid_channels, in_chan, kernel, **cnn_kwargs)       # + e1

        # 1x1 convs to align encoder skip features to decoder features if needed
        self.align_e3 = nn.Conv2d(hid_channels, hid_channels, 1)
        self.align_e2 = nn.Conv2d(hid_channels, hid_channels, 1)
        self.align_e1 = nn.Conv2d(hid_channels, hid_channels, 1)

    def forward(self, z, skips):
        batch_size = z.size(0)
        x = torch.relu(self.fc1(z))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = x.view(batch_size, *self.reshape)

        x = torch.relu(self.up1(x))  # → 8x8

        e3 = F.interpolate(skips[2], size=x.shape[2:], mode='nearest')
        e3 = self.align_e3(e3)
        x = torch.relu(self.up2(x + e3))  # → 16x16

        e2 = F.interpolate(skips[1], size=x.shape[2:], mode='nearest')
        e2 = self.align_e2(e2)
        x = torch.relu(self.up3(x + e2))  # → 32x32

        e1 = F.interpolate(skips[0], size=x.shape[2:], mode='nearest')
        e1 = self.align_e1(e1)
        x = torch.sigmoid(self.up4(x + e1))  # → 64x64

        return x

# %%
# --- Define VAE ---
class VAE(nn.Module):
    def __init__(self, z_dim=64, hidden_dim=256, input_dim=IMG_SIZE*IMG_SIZE*3):
        super().__init__()
        self.input_dim = input_dim
        self.output_dim = input_dim  # Assuming output is same as input for reconstruction

        # Define the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim, self.input_dim)
        self.decoder = Decoder(z_dim, hidden_dim, self.output_dim)
        self.z_dim = z_dim

    # Define the model p(y|z)p(z)
    def model(self, x, y, beta = 5):
        pyro.module("decoder", self.decoder)
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = torch.zeros(x.shape[0], self.z_dim, dtype=x.dtype, device=device)
            z_scale = torch.ones(x.shape[0], self.z_dim, dtype=x.dtype, device=device)
            skips = [torch.zeros(x.shape[0], 32, 16, 16, dtype=x.dtype, device=device) for _ in range(3)]
            # sample from prior
            with pyro.poutine.scale(scale=beta):
                # sample the latent code z from the prior p(z)
                z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            
            # decode the latent code z
            out = self.decoder.forward(z, skips)
            # sample from the decoder p(y|z)
            pyro.sample("obs", dist.Bernoulli(out, validate_args=False).to_event(3), obs=y)

            return out

    # Define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x, y, beta = 5):
        # use the encoder to get the parameters used to define q(z|x)
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            with pyro.poutine.scale(scale=beta):
                # get the parameters of the variational distribution q(z|x)
                z_loc, z_scale, _ = self.encoder.forward(x)
                z_scale = torch.exp(z_scale * 0.5)  # Convert log variance to standard deviation
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
def train(svi, train_loader):
    # initialize loss accumulator
    epoch_loss = 0.

    for img, mask in train_loader:

        # move data to device
        img = img.to(device)
        mask = mask.to(device)
    
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(img, mask)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train



def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for img, mask in test_loader:
        # move data to device
        img = img.to(device)
        mask = mask.to(device)
        
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(img, mask)  
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
print(train_loader.dataset[0][0].shape)
print(train_loader.dataset[1][1].shape)
# Out:
# torch.Size([1, 64, 64])
# torch.Size([1, 64, 64])

# %%
# --- Training the VAE ---
num_epochs = 500
test_frequency = 5
lr = 1e-3

def run_model(num_epochs=num_epochs, test_frequency=test_frequency, lr=lr):
    pyro.clear_param_store()  # clear everything before instantiation
    vae = VAE(z_dim = 64, hidden_dim=248, input_dim=IMG_SIZE*IMG_SIZE*3)
    vae.to(device)

    # setup the optimizer
    optimizer = Adam({"lr": lr})
    svi = SVI(vae.model, vae.guide, optimizer, loss=pyro.infer.Trace_ELBO())

    train_elbo = []
    test_elbo = []
    # training loop
    for epoch in range(num_epochs):
        total_epoch_loss_train = train(svi, train_loader)
        train_elbo.append(-total_epoch_loss_train)
        print(f"[Epoch {epoch+1}]")
        print("Mean train loss: %.4f" %  total_epoch_loss_train)

        if epoch % test_frequency == 0:
            # report test diagnostics
            total_epoch_loss_test = evaluate(svi, test_loader)
            test_elbo.append(-total_epoch_loss_test)
            print("Mean test loss: %.4f" % total_epoch_loss_test)
        print("")
    return vae

vae = run_model(num_epochs=num_epochs, test_frequency=test_frequency, lr=lr)
# Out:
# [Epoch 1]
# Mean train loss: 1084.2054
# Mean test loss: 487.0180
#
# [Epoch 2]
# Mean train loss: 480.4959
#
# [Epoch 3]
# Mean train loss: 470.6657
#
# [Epoch 4]
# Mean train loss: 469.0136
#
# [Epoch 5]
# Mean train loss: 467.0830
#
# [Epoch 6]
# Mean train loss: 465.6450
# Mean test loss: 451.8241
#
# [Epoch 7]
# Mean train loss: 465.5041
#
# [Epoch 8]
# Mean train loss: 460.8220
#
# [Epoch 9]
# Mean train loss: 459.4143
#
# [Epoch 10]
# Mean train loss: 455.3872
#
# [Epoch 11]
# Mean train loss: 452.4992
# Mean test loss: 445.2591
#
# [Epoch 12]
# Mean train loss: 449.4569
#
# [Epoch 13]
# Mean train loss: 444.9520
#
# [Epoch 14]
# Mean train loss: 444.5840
#
# [Epoch 15]
# Mean train loss: 442.4770
#
# [Epoch 16]
# Mean train loss: 437.6662
# Mean test loss: 426.6396
#
# [Epoch 17]
# Mean train loss: 434.4022
#
# [Epoch 18]
# Mean train loss: 434.4277
#
# [Epoch 19]
# Mean train loss: 428.4704
#
# [Epoch 20]
# Mean train loss: 426.6313
#
# [Epoch 21]
# Mean train loss: 425.2730
# Mean test loss: 424.9131
#
# [Epoch 22]
# Mean train loss: 420.4200
#
# [Epoch 23]
# Mean train loss: 416.8868
#
# [Epoch 24]
# Mean train loss: 417.4250
#
# [Epoch 25]
# Mean train loss: 415.1889
#
# [Epoch 26]
# Mean train loss: 411.3606
# Mean test loss: 415.6241
#
# [Epoch 27]
# Mean train loss: 406.8156
#
# [Epoch 28]
# Mean train loss: 401.5296
#
# [Epoch 29]
# Mean train loss: 398.1464
#
# [Epoch 30]
# Mean train loss: 396.7346
#
# [Epoch 31]
# Mean train loss: 391.3161
# Mean test loss: 396.4200
#
# [Epoch 32]
# Mean train loss: 387.0107
#
# [Epoch 33]
# Mean train loss: 383.8328
#
# [Epoch 34]
# Mean train loss: 379.1708
#
# [Epoch 35]
# Mean train loss: 375.2145
#
# [Epoch 36]
# Mean train loss: 373.1593
# Mean test loss: 377.1838
#
# [Epoch 37]
# Mean train loss: 370.9509
#
# [Epoch 38]
# Mean train loss: 370.6908
#
# [Epoch 39]
# Mean train loss: 367.7794
#
# [Epoch 40]
# Mean train loss: 366.4397
#
# [Epoch 41]
# Mean train loss: 363.4340
# Mean test loss: 373.7421
#
# [Epoch 42]
# Mean train loss: 360.9256
#
# [Epoch 43]
# Mean train loss: 361.3974
#
# [Epoch 44]
# Mean train loss: 360.4209
#
# [Epoch 45]
# Mean train loss: 357.2436
#
# [Epoch 46]
# Mean train loss: 355.2099
# Mean test loss: 369.4629
#
# [Epoch 47]
# Mean train loss: 354.8833
#
# [Epoch 48]
# Mean train loss: 355.0667
#
# [Epoch 49]
# Mean train loss: 353.1145
#
# [Epoch 50]
# Mean train loss: 351.3352
#
# [Epoch 51]
# Mean train loss: 350.2084
# Mean test loss: 360.7503
#
# [Epoch 52]
# Mean train loss: 348.9110
#
# [Epoch 53]
# Mean train loss: 348.5832
#
# [Epoch 54]
# Mean train loss: 348.8522
#
# [Epoch 55]
# Mean train loss: 347.3608
#
# [Epoch 56]
# Mean train loss: 344.8385
# Mean test loss: 357.9021
#
# [Epoch 57]
# Mean train loss: 345.6408
#
# [Epoch 58]
# Mean train loss: 344.1713
#
# [Epoch 59]
# Mean train loss: 343.9723
#
# [Epoch 60]
# Mean train loss: 342.5272
#
# [Epoch 61]
# Mean train loss: 342.1596
# Mean test loss: 361.1645
#
# [Epoch 62]
# Mean train loss: 342.8998
#
# [Epoch 63]
# Mean train loss: 342.3613
#
# [Epoch 64]
# Mean train loss: 341.8142
#
# [Epoch 65]
# Mean train loss: 340.2880
#
# [Epoch 66]
# Mean train loss: 339.6562
# Mean test loss: 356.1631
#
# [Epoch 67]
# Mean train loss: 339.0576
#
# [Epoch 68]
# Mean train loss: 338.3411
#
# [Epoch 69]
# Mean train loss: 337.3588
#
# [Epoch 70]
# Mean train loss: 337.5805
#
# [Epoch 71]
# Mean train loss: 338.2085
# Mean test loss: 358.5280
#
# [Epoch 72]
# Mean train loss: 338.0589
#
# [Epoch 73]
# Mean train loss: 336.9143
#
# [Epoch 74]
# Mean train loss: 336.0099
#
# [Epoch 75]
# Mean train loss: 335.3479
#
# [Epoch 76]
# Mean train loss: 335.2992
# Mean test loss: 354.2049
#
# [Epoch 77]
# Mean train loss: 335.3978
#
# [Epoch 78]
# Mean train loss: 335.1002
#
# [Epoch 79]
# Mean train loss: 334.7568
#
# [Epoch 80]
# Mean train loss: 334.2275
#
# [Epoch 81]
# Mean train loss: 333.7307
# Mean test loss: 354.8184
#
# [Epoch 82]
# Mean train loss: 333.6137
#
# [Epoch 83]
# Mean train loss: 332.8896
#
# [Epoch 84]
# Mean train loss: 333.8927
#
# [Epoch 85]
# Mean train loss: 332.5089
#
# [Epoch 86]
# Mean train loss: 333.0356
# Mean test loss: 359.7077
#
# [Epoch 87]
# Mean train loss: 332.9256
#
# [Epoch 88]
# Mean train loss: 331.6141
#
# [Epoch 89]
# Mean train loss: 332.4523
#
# [Epoch 90]
# Mean train loss: 332.4106
#
# [Epoch 91]
# Mean train loss: 332.4876
# Mean test loss: 353.7010
#
# [Epoch 92]
# Mean train loss: 331.7881
#
# [Epoch 93]
# Mean train loss: 332.5141
#
# [Epoch 94]
# Mean train loss: 332.5028
#
# [Epoch 95]
# Mean train loss: 331.0912
#
# [Epoch 96]
# Mean train loss: 330.9403
# Mean test loss: 358.3316
#
# [Epoch 97]
# Mean train loss: 330.7008
#
# [Epoch 98]
# Mean train loss: 330.3452
#
# [Epoch 99]
# Mean train loss: 330.8437
#
# [Epoch 100]
# Mean train loss: 331.5383
#
# [Epoch 101]
# Mean train loss: 330.9947
# Mean test loss: 362.3804
#
# [Epoch 102]
# Mean train loss: 329.8098
#
# [Epoch 103]
# Mean train loss: 329.7865
#
# [Epoch 104]
# Mean train loss: 329.5098
#
# [Epoch 105]
# Mean train loss: 329.3939
#
# [Epoch 106]
# Mean train loss: 328.8668
# Mean test loss: 356.1731
#
# [Epoch 107]
# Mean train loss: 329.3262
#
# [Epoch 108]
# Mean train loss: 328.2490
#
# [Epoch 109]
# Mean train loss: 328.6443
#
# [Epoch 110]
# Mean train loss: 328.5385
#
# [Epoch 111]
# Mean train loss: 328.9014
# Mean test loss: 364.7139
#
# [Epoch 112]
# Mean train loss: 328.8511
#
# [Epoch 113]
# Mean train loss: 328.1415
#
# [Epoch 114]
# Mean train loss: 327.8510
#
# [Epoch 115]
# Mean train loss: 328.6278
#
# [Epoch 116]
# Mean train loss: 327.8184
# Mean test loss: 358.8442
#
# [Epoch 117]
# Mean train loss: 327.1282
#
# [Epoch 118]
# Mean train loss: 328.0603
#
# [Epoch 119]
# Mean train loss: 328.9775
#
# [Epoch 120]
# Mean train loss: 327.5587
#
# [Epoch 121]
# Mean train loss: 327.7630
# Mean test loss: 358.1972
#
# [Epoch 122]
# Mean train loss: 327.8698
#
# [Epoch 123]
# Mean train loss: 327.5964
#
# [Epoch 124]
# Mean train loss: 327.5812
#
# [Epoch 125]
# Mean train loss: 327.1075
#
# [Epoch 126]
# Mean train loss: 327.0443
# Mean test loss: 356.9776
#
# [Epoch 127]
# Mean train loss: 327.1216
#
# [Epoch 128]
# Mean train loss: 327.9299
#
# [Epoch 129]
# Mean train loss: 327.5756
#
# [Epoch 130]
# Mean train loss: 326.8657
#
# [Epoch 131]
# Mean train loss: 326.6748
# Mean test loss: 355.8682
#
# [Epoch 132]
# Mean train loss: 326.7270
#
# [Epoch 133]
# Mean train loss: 326.5712
#
# [Epoch 134]
# Mean train loss: 326.2003
#
# [Epoch 135]
# Mean train loss: 327.0745
#
# [Epoch 136]
# Mean train loss: 327.2126
# Mean test loss: 358.6911
#
# [Epoch 137]
# Mean train loss: 327.1705
#
# [Epoch 138]
# Mean train loss: 326.2434
#
# [Epoch 139]
# Mean train loss: 327.0582
#
# [Epoch 140]
# Mean train loss: 326.2407
#
# [Epoch 141]
# Mean train loss: 325.9208
# Mean test loss: 358.9136
#
# [Epoch 142]
# Mean train loss: 325.0459
#
# [Epoch 143]
# Mean train loss: 325.8971
#
# [Epoch 144]
# Mean train loss: 326.5460
#
# [Epoch 145]
# Mean train loss: 326.7454
#
# [Epoch 146]
# Mean train loss: 325.7891
# Mean test loss: 357.8080
#
# [Epoch 147]
# Mean train loss: 325.0335
#
# [Epoch 148]
# Mean train loss: 324.1934
#
# [Epoch 149]
# Mean train loss: 325.8033
#
# [Epoch 150]
# Mean train loss: 326.3212
#
# [Epoch 151]
# Mean train loss: 325.8871
# Mean test loss: 360.2836
#
# [Epoch 152]
# Mean train loss: 325.4994
#
# [Epoch 153]
# Mean train loss: 325.0303
#
# [Epoch 154]
# Mean train loss: 325.1588
#
# [Epoch 155]
# Mean train loss: 324.8325
#
# [Epoch 156]
# Mean train loss: 324.8812
# Mean test loss: 353.4310
#
# [Epoch 157]
# Mean train loss: 324.2888
#
# [Epoch 158]
# Mean train loss: 324.3464
#
# [Epoch 159]
# Mean train loss: 324.8927
#
# [Epoch 160]
# Mean train loss: 324.8039
#
# [Epoch 161]
# Mean train loss: 324.5601
# Mean test loss: 356.2592
#
# [Epoch 162]
# Mean train loss: 324.4976
#
# [Epoch 163]
# Mean train loss: 325.7891
#
# [Epoch 164]
# Mean train loss: 324.2783
#
# [Epoch 165]
# Mean train loss: 324.0499
#
# [Epoch 166]
# Mean train loss: 323.7294
# Mean test loss: 361.7807
#
# [Epoch 167]
# Mean train loss: 324.3003
#
# [Epoch 168]
# Mean train loss: 324.7336
#
# [Epoch 169]
# Mean train loss: 325.3884
#
# [Epoch 170]
# Mean train loss: 324.8133
#
# [Epoch 171]
# Mean train loss: 324.8548
# Mean test loss: 364.1081
#
# [Epoch 172]
# Mean train loss: 323.9227
#
# [Epoch 173]
# Mean train loss: 324.3435
#
# [Epoch 174]
# Mean train loss: 324.8073
#
# [Epoch 175]
# Mean train loss: 323.5658
#
# [Epoch 176]
# Mean train loss: 323.4211
# Mean test loss: 364.4343
#
# [Epoch 177]
# Mean train loss: 324.4396
#
# [Epoch 178]
# Mean train loss: 324.4374
#
# [Epoch 179]
# Mean train loss: 323.7096
#
# [Epoch 180]
# Mean train loss: 323.7390
#
# [Epoch 181]
# Mean train loss: 323.4167
# Mean test loss: 362.6385
#
# [Epoch 182]
# Mean train loss: 323.0325
#
# [Epoch 183]
# Mean train loss: 322.7351
#
# [Epoch 184]
# Mean train loss: 324.2799
#
# [Epoch 185]
# Mean train loss: 324.0915
#
# [Epoch 186]
# Mean train loss: 322.9313
# Mean test loss: 358.4849
#
# [Epoch 187]
# Mean train loss: 323.3156
#
# [Epoch 188]
# Mean train loss: 323.6484
#
# [Epoch 189]
# Mean train loss: 323.4144
#
# [Epoch 190]
# Mean train loss: 322.5735
#
# [Epoch 191]
# Mean train loss: 322.8513
# Mean test loss: 364.2968
#
# [Epoch 192]
# Mean train loss: 322.6439
#
# [Epoch 193]
# Mean train loss: 323.0514
#
# [Epoch 194]
# Mean train loss: 322.8796
#
# [Epoch 195]
# Mean train loss: 323.6074
#
# [Epoch 196]
# Mean train loss: 323.2043
# Mean test loss: 365.2218
#
# [Epoch 197]
# Mean train loss: 323.0838
#
# [Epoch 198]
# Mean train loss: 322.5200
#
# [Epoch 199]
# Mean train loss: 322.4725
#
# [Epoch 200]
# Mean train loss: 322.8778
#
# [Epoch 201]
# Mean train loss: 322.1273
# Mean test loss: 365.0125
#
# [Epoch 202]
# Mean train loss: 321.9569
#
# [Epoch 203]
# Mean train loss: 322.4691
#
# [Epoch 204]
# Mean train loss: 322.7738
#
# [Epoch 205]
# Mean train loss: 322.5771
#
# [Epoch 206]
# Mean train loss: 322.8252
# Mean test loss: 359.8826
#
# [Epoch 207]
# Mean train loss: 322.3559
#
# [Epoch 208]
# Mean train loss: 322.6493
#
# [Epoch 209]
# Mean train loss: 323.6671
#
# [Epoch 210]
# Mean train loss: 323.1362
#
# [Epoch 211]
# Mean train loss: 322.3654
# Mean test loss: 361.6972
#
# [Epoch 212]
# Mean train loss: 322.1478
#
# [Epoch 213]
# Mean train loss: 322.0760
#
# [Epoch 214]
# Mean train loss: 321.9228
#
# [Epoch 215]
# Mean train loss: 321.6749
#
# [Epoch 216]
# Mean train loss: 322.1158
# Mean test loss: 360.2041
#
# [Epoch 217]
# Mean train loss: 322.0422
#
# [Epoch 218]
# Mean train loss: 322.4158
#
# [Epoch 219]
# Mean train loss: 321.8065
#
# [Epoch 220]
# Mean train loss: 321.5666
#
# [Epoch 221]
# Mean train loss: 321.0011
# Mean test loss: 362.1344
#
# [Epoch 222]
# Mean train loss: 321.3139
#
# [Epoch 223]
# Mean train loss: 322.7211
#
# [Epoch 224]
# Mean train loss: 322.0098
#
# [Epoch 225]
# Mean train loss: 322.5965
#
# [Epoch 226]
# Mean train loss: 321.8227
# Mean test loss: 369.0883
#
# [Epoch 227]
# Mean train loss: 321.3370
#
# [Epoch 228]
# Mean train loss: 321.9647
#
# [Epoch 229]
# Mean train loss: 321.3366
#
# [Epoch 230]
# Mean train loss: 321.0697
#
# [Epoch 231]
# Mean train loss: 320.8949
# Mean test loss: 366.7318
#
# [Epoch 232]
# Mean train loss: 322.3084
#
# [Epoch 233]
# Mean train loss: 321.6257
#
# [Epoch 234]
# Mean train loss: 320.9432
#
# [Epoch 235]
# Mean train loss: 321.0334
#
# [Epoch 236]
# Mean train loss: 321.1353
# Mean test loss: 368.0507
#
# [Epoch 237]
# Mean train loss: 321.0091
#
# [Epoch 238]
# Mean train loss: 320.5926
#
# [Epoch 239]
# Mean train loss: 320.8236
#
# [Epoch 240]
# Mean train loss: 322.0327
#
# [Epoch 241]
# Mean train loss: 322.9697
# Mean test loss: 366.5251
#
# [Epoch 242]
# Mean train loss: 321.2715
#
# [Epoch 243]
# Mean train loss: 321.4713
#
# [Epoch 244]
# Mean train loss: 321.4594
#
# [Epoch 245]
# Mean train loss: 320.4611
#
# [Epoch 246]
# Mean train loss: 320.1411
# Mean test loss: 363.4212
#
# [Epoch 247]
# Mean train loss: 320.0227
#
# [Epoch 248]
# Mean train loss: 321.3318
#
# [Epoch 249]
# Mean train loss: 322.0964
#
# [Epoch 250]
# Mean train loss: 321.2894
#
# [Epoch 251]
# Mean train loss: 321.0858
# Mean test loss: 365.3717
#
# [Epoch 252]
# Mean train loss: 320.3640
#
# [Epoch 253]
# Mean train loss: 321.6739
#
# [Epoch 254]
# Mean train loss: 320.8516
#
# [Epoch 255]
# Mean train loss: 319.9721
#
# [Epoch 256]
# Mean train loss: 319.8787
# Mean test loss: 361.5080
#
# [Epoch 257]
# Mean train loss: 319.8105
#
# [Epoch 258]
# Mean train loss: 319.8309
#
# [Epoch 259]
# Mean train loss: 319.9026
#
# [Epoch 260]
# Mean train loss: 320.1812
#
# [Epoch 261]
# Mean train loss: 320.5289
# Mean test loss: 374.9883
#
# [Epoch 262]
# Mean train loss: 320.8485
#
# [Epoch 263]
# Mean train loss: 320.3836
#
# [Epoch 264]
# Mean train loss: 320.4856
#
# [Epoch 265]
# Mean train loss: 319.8064
#
# [Epoch 266]
# Mean train loss: 319.8850
# Mean test loss: 371.3047
#
# [Epoch 267]
# Mean train loss: 320.3197
#
# [Epoch 268]
# Mean train loss: 321.6182
#
# [Epoch 269]
# Mean train loss: 320.6090
#
# [Epoch 270]
# Mean train loss: 319.7402
#
# [Epoch 271]
# Mean train loss: 320.1516
# Mean test loss: 371.8733
#
# [Epoch 272]
# Mean train loss: 319.8418
#
# [Epoch 273]
# Mean train loss: 320.3828
#
# [Epoch 274]
# Mean train loss: 320.1754
#
# [Epoch 275]
# Mean train loss: 319.7669
#
# [Epoch 276]
# Mean train loss: 319.8549
# Mean test loss: 370.3811
#
# [Epoch 277]
# Mean train loss: 321.6052
#
# [Epoch 278]
# Mean train loss: 320.5744
#
# [Epoch 279]
# Mean train loss: 320.2431
#
# [Epoch 280]
# Mean train loss: 320.1203
#
# [Epoch 281]
# Mean train loss: 320.4219
# Mean test loss: 363.6925
#
# [Epoch 282]
# Mean train loss: 319.7333
#
# [Epoch 283]
# Mean train loss: 318.9610
#
# [Epoch 284]
# Mean train loss: 319.5595
#
# [Epoch 285]
# Mean train loss: 319.3783
#
# [Epoch 286]
# Mean train loss: 319.2602
# Mean test loss: 371.2355
#
# [Epoch 287]
# Mean train loss: 319.3872
#
# [Epoch 288]
# Mean train loss: 320.3363
#
# [Epoch 289]
# Mean train loss: 320.5189
#
# [Epoch 290]
# Mean train loss: 319.9259
#
# [Epoch 291]
# Mean train loss: 319.3514
# Mean test loss: 369.1114
#
# [Epoch 292]
# Mean train loss: 319.0560
#
# [Epoch 293]
# Mean train loss: 319.2678
#
# [Epoch 294]
# Mean train loss: 319.5011
#
# [Epoch 295]
# Mean train loss: 319.2784
#
# [Epoch 296]
# Mean train loss: 318.8745
# Mean test loss: 370.2021
#
# [Epoch 297]
# Mean train loss: 319.2952
#
# [Epoch 298]
# Mean train loss: 320.1130
#
# [Epoch 299]
# Mean train loss: 320.4118
#
# [Epoch 300]
# Mean train loss: 320.1756
#
# [Epoch 301]
# Mean train loss: 319.7171
# Mean test loss: 368.8469
#
# [Epoch 302]
# Mean train loss: 319.7745
#
# [Epoch 303]
# Mean train loss: 319.0452
#
# [Epoch 304]
# Mean train loss: 318.7420
#
# [Epoch 305]
# Mean train loss: 318.6674
#
# [Epoch 306]
# Mean train loss: 319.3639
# Mean test loss: 372.4204
#
# [Epoch 307]
# Mean train loss: 319.3421
#
# [Epoch 308]
# Mean train loss: 318.8857
#
# [Epoch 309]
# Mean train loss: 318.6960
#
# [Epoch 310]
# Mean train loss: 318.9524
#
# [Epoch 311]
# Mean train loss: 319.2128
# Mean test loss: 370.0351
#
# [Epoch 312]
# Mean train loss: 319.4588
#
# [Epoch 313]
# Mean train loss: 319.2388
#
# [Epoch 314]
# Mean train loss: 319.4981
#
# [Epoch 315]
# Mean train loss: 318.5574
#
# [Epoch 316]
# Mean train loss: 318.6656
# Mean test loss: 376.2195
#
# [Epoch 317]
# Mean train loss: 318.9373
#
# [Epoch 318]
# Mean train loss: 320.5609
#
# [Epoch 319]
# Mean train loss: 319.6626
#
# [Epoch 320]
# Mean train loss: 318.2354
#
# [Epoch 321]
# Mean train loss: 318.4842
# Mean test loss: 373.1547
#
# [Epoch 322]
# Mean train loss: 319.7280
#
# [Epoch 323]
# Mean train loss: 319.3603
#
# [Epoch 324]
# Mean train loss: 319.0278
#
# [Epoch 325]
# Mean train loss: 319.3692
#
# [Epoch 326]
# Mean train loss: 319.0318
# Mean test loss: 370.7649
#
# [Epoch 327]
# Mean train loss: 318.6741
#
# [Epoch 328]
# Mean train loss: 318.0457
#
# [Epoch 329]
# Mean train loss: 317.7730
#
# [Epoch 330]
# Mean train loss: 318.2852
#
# [Epoch 331]
# Mean train loss: 318.6359
# Mean test loss: 381.4727
#
# [Epoch 332]
# Mean train loss: 318.9563
#
# [Epoch 333]
# Mean train loss: 318.3595
#
# [Epoch 334]
# Mean train loss: 318.8314
#
# [Epoch 335]
# Mean train loss: 318.8170
#
# [Epoch 336]
# Mean train loss: 319.3359
# Mean test loss: 373.5394
#
# [Epoch 337]
# Mean train loss: 319.2985
#
# [Epoch 338]
# Mean train loss: 319.3757
#
# [Epoch 339]
# Mean train loss: 320.0854
#
# [Epoch 340]
# Mean train loss: 318.8957
#
# [Epoch 341]
# Mean train loss: 318.1635
# Mean test loss: 374.1963
#
# [Epoch 342]
# Mean train loss: 317.7654
#
# [Epoch 343]
# Mean train loss: 318.1757
#
# [Epoch 344]
# Mean train loss: 318.0866
#
# [Epoch 345]
# Mean train loss: 317.7029
#
# [Epoch 346]
# Mean train loss: 317.9427
# Mean test loss: 373.9641
#
# [Epoch 347]
# Mean train loss: 318.1844
#
# [Epoch 348]
# Mean train loss: 319.8719
#
# [Epoch 349]
# Mean train loss: 318.5112
#
# [Epoch 350]
# Mean train loss: 318.2809
#
# [Epoch 351]
# Mean train loss: 318.5086
# Mean test loss: 363.7897
#
# [Epoch 352]
# Mean train loss: 319.0956
#
# [Epoch 353]
# Mean train loss: 317.9417
#
# [Epoch 354]
# Mean train loss: 317.8756
#
# [Epoch 355]
# Mean train loss: 317.9053
#
# [Epoch 356]
# Mean train loss: 317.4044
# Mean test loss: 372.8933
#
# [Epoch 357]
# Mean train loss: 318.8502
#
# [Epoch 358]
# Mean train loss: 318.5701
#
# [Epoch 359]
# Mean train loss: 318.8298
#
# [Epoch 360]
# Mean train loss: 318.2277
#
# [Epoch 361]
# Mean train loss: 317.3758
# Mean test loss: 366.9889
#
# [Epoch 362]
# Mean train loss: 317.7285
#
# [Epoch 363]
# Mean train loss: 317.7833
#
# [Epoch 364]
# Mean train loss: 318.0580
#
# [Epoch 365]
# Mean train loss: 317.3700
#
# [Epoch 366]
# Mean train loss: 317.3061
# Mean test loss: 373.1363
#
# [Epoch 367]
# Mean train loss: 318.2270
#
# [Epoch 368]
# Mean train loss: 318.1892
#
# [Epoch 369]
# Mean train loss: 317.4320
#
# [Epoch 370]
# Mean train loss: 317.4677
#
# [Epoch 371]
# Mean train loss: 317.3933
# Mean test loss: 376.8728
#
# [Epoch 372]
# Mean train loss: 318.1331
#
# [Epoch 373]
# Mean train loss: 318.3001
#
# [Epoch 374]
# Mean train loss: 318.5873
#
# [Epoch 375]
# Mean train loss: 317.5626
#
# [Epoch 376]
# Mean train loss: 317.5321
# Mean test loss: 376.5227
#
# [Epoch 377]
# Mean train loss: 317.8412
#
# [Epoch 378]
# Mean train loss: 317.4070
#
# [Epoch 379]
# Mean train loss: 317.8248
#
# [Epoch 380]
# Mean train loss: 318.0036
#
# [Epoch 381]
# Mean train loss: 317.5162
# Mean test loss: 372.3504
#
# [Epoch 382]
# Mean train loss: 317.5472
#
# [Epoch 383]
# Mean train loss: 317.2632
#
# [Epoch 384]
# Mean train loss: 317.0690
#
# [Epoch 385]
# Mean train loss: 317.8782
#
# [Epoch 386]
# Mean train loss: 317.6287
# Mean test loss: 378.6769
#
# [Epoch 387]
# Mean train loss: 317.2216
#
# [Epoch 388]
# Mean train loss: 317.4638
#
# [Epoch 389]
# Mean train loss: 317.4483
#
# [Epoch 390]
# Mean train loss: 316.9795
#
# [Epoch 391]
# Mean train loss: 317.1232
# Mean test loss: 371.0787
#
# [Epoch 392]
# Mean train loss: 317.5056
#
# [Epoch 393]
# Mean train loss: 317.5010
#
# [Epoch 394]
# Mean train loss: 316.8921
#
# [Epoch 395]
# Mean train loss: 316.9824
#
# [Epoch 396]
# Mean train loss: 317.0105
# Mean test loss: 371.5639
#
# [Epoch 397]
# Mean train loss: 317.2494
#
# [Epoch 398]
# Mean train loss: 317.3133
#
# [Epoch 399]
# Mean train loss: 318.2957
#
# [Epoch 400]
# Mean train loss: 318.4428
#
# [Epoch 401]
# Mean train loss: 317.3312
# Mean test loss: 371.1146
#
# [Epoch 402]
# Mean train loss: 317.2691
#
# [Epoch 403]
# Mean train loss: 319.9195
#
# [Epoch 404]
# Mean train loss: 318.6534
#
# [Epoch 405]
# Mean train loss: 317.7890
#
# [Epoch 406]
# Mean train loss: 316.9174
# Mean test loss: 376.2845
#
# [Epoch 407]
# Mean train loss: 317.1716
#
# [Epoch 408]
# Mean train loss: 316.7907
#
# [Epoch 409]
# Mean train loss: 316.6489
#
# [Epoch 410]
# Mean train loss: 316.8021
#
# [Epoch 411]
# Mean train loss: 316.9147
# Mean test loss: 372.4197
#
# [Epoch 412]
# Mean train loss: 316.7768
#
# [Epoch 413]
# Mean train loss: 316.4628
#
# [Epoch 414]
# Mean train loss: 316.3668
#
# [Epoch 415]
# Mean train loss: 316.8694
#
# [Epoch 416]
# Mean train loss: 317.5087
# Mean test loss: 381.5245
#
# [Epoch 417]
# Mean train loss: 316.9798
#
# [Epoch 418]
# Mean train loss: 316.6302
#
# [Epoch 419]
# Mean train loss: 316.2482
#
# [Epoch 420]
# Mean train loss: 316.4544
#
# [Epoch 421]
# Mean train loss: 316.8330
# Mean test loss: 376.8161
#
# [Epoch 422]
# Mean train loss: 317.1219
#
# [Epoch 423]
# Mean train loss: 317.1857
#
# [Epoch 424]
# Mean train loss: 317.3096
#
# [Epoch 425]
# Mean train loss: 318.1461
#
# [Epoch 426]
# Mean train loss: 322.1251
# Mean test loss: 370.2840
#
# [Epoch 427]
# Mean train loss: 320.3565
#
# [Epoch 428]
# Mean train loss: 317.8599
#
# [Epoch 429]
# Mean train loss: 316.7510
#
# [Epoch 430]
# Mean train loss: 316.3257
#
# [Epoch 431]
# Mean train loss: 316.3662
# Mean test loss: 378.8102
#
# [Epoch 432]
# Mean train loss: 316.7303
#
# [Epoch 433]
# Mean train loss: 316.8713
#
# [Epoch 434]
# Mean train loss: 316.3652
#
# [Epoch 435]
# Mean train loss: 315.9116
#
# [Epoch 436]
# Mean train loss: 315.7096
# Mean test loss: 377.1698
#
# [Epoch 437]
# Mean train loss: 315.9343
#
# [Epoch 438]
# Mean train loss: 316.1345
#
# [Epoch 439]
# Mean train loss: 316.6680
#
# [Epoch 440]
# Mean train loss: 317.7590
#
# [Epoch 441]
# Mean train loss: 317.9969
# Mean test loss: 371.9162
#
# [Epoch 442]
# Mean train loss: 316.9477
#
# [Epoch 443]
# Mean train loss: 316.6003
#
# [Epoch 444]
# Mean train loss: 316.7024
#
# [Epoch 445]
# Mean train loss: 316.6836
#
# [Epoch 446]
# Mean train loss: 316.5187
# Mean test loss: 364.0753
#
# [Epoch 447]
# Mean train loss: 316.7060
#
# [Epoch 448]
# Mean train loss: 317.1503
#
# [Epoch 449]
# Mean train loss: 316.4279
#
# [Epoch 450]
# Mean train loss: 316.4441
#
# [Epoch 451]
# Mean train loss: 316.7771
# Mean test loss: 374.4478
#
# [Epoch 452]
# Mean train loss: 316.9856
#
# [Epoch 453]
# Mean train loss: 316.7810
#
# [Epoch 454]
# Mean train loss: 316.9793
#
# [Epoch 455]
# Mean train loss: 316.8290
#
# [Epoch 456]
# Mean train loss: 316.6589
# Mean test loss: 373.2054
#
# [Epoch 457]
# Mean train loss: 316.2004
#
# [Epoch 458]
# Mean train loss: 316.9090
#
# [Epoch 459]
# Mean train loss: 316.3487
#
# [Epoch 460]
# Mean train loss: 315.8696
#
# [Epoch 461]
# Mean train loss: 317.1066
# Mean test loss: 373.4363
#
# [Epoch 462]
# Mean train loss: 316.7654
#
# [Epoch 463]
# Mean train loss: 316.5243
#
# [Epoch 464]
# Mean train loss: 316.2237
#
# [Epoch 465]
# Mean train loss: 316.4309
#
# [Epoch 466]
# Mean train loss: 316.0887
# Mean test loss: 374.0354
#
# [Epoch 467]
# Mean train loss: 315.4995
#
# [Epoch 468]
# Mean train loss: 316.2362
#
# [Epoch 469]
# Mean train loss: 316.2649
#
# [Epoch 470]
# Mean train loss: 316.1846
#
# [Epoch 471]
# Mean train loss: 316.1021
# Mean test loss: 375.8922
#
# [Epoch 472]
# Mean train loss: 315.6134
#
# [Epoch 473]
# Mean train loss: 315.6759
#
# [Epoch 474]
# Mean train loss: 316.2678
#
# [Epoch 475]
# Mean train loss: 316.6996
#
# [Epoch 476]
# Mean train loss: 318.2009
# Mean test loss: 375.0902
#
# [Epoch 477]
# Mean train loss: 317.2218
#
# [Epoch 478]
# Mean train loss: 316.1923
#
# [Epoch 479]
# Mean train loss: 316.7257
#
# [Epoch 480]
# Mean train loss: 316.6129
#
# [Epoch 481]
# Mean train loss: 315.6448
# Mean test loss: 380.3914
#
# [Epoch 482]
# Mean train loss: 315.7134
#
# [Epoch 483]
# Mean train loss: 316.4412
#
# [Epoch 484]
# Mean train loss: 316.5878
#
# [Epoch 485]
# Mean train loss: 316.7701
#
# [Epoch 486]
# Mean train loss: 316.6003
# Mean test loss: 380.3204
#
# [Epoch 487]
# Mean train loss: 318.1530
#
# [Epoch 488]
# Mean train loss: 316.8587
#
# [Epoch 489]
# Mean train loss: 315.7480
#
# [Epoch 490]
# Mean train loss: 315.2446
#
# [Epoch 491]
# Mean train loss: 315.4940
# Mean test loss: 375.6977
#
# [Epoch 492]
# Mean train loss: 316.0241
#
# [Epoch 493]
# Mean train loss: 316.3515
#
# [Epoch 494]
# Mean train loss: 316.0481
#
# [Epoch 495]
# Mean train loss: 316.3380
#
# [Epoch 496]
# Mean train loss: 316.0424
# Mean test loss: 368.2139
#
# [Epoch 497]
# Mean train loss: 315.6460
#
# [Epoch 498]
# Mean train loss: 316.3642
#
# [Epoch 499]
# Mean train loss: 316.2635
#
# [Epoch 500]
# Mean train loss: 315.7163

# %%
def predict(x): 
    posterior = Predictive(vae.model, guide=vae.guide, num_samples=1)
    samples = posterior(x, None)
    return samples["obs"]

# %%
def visualize_predictions(model, loader, num_images=5):
    model.eval()
    images, true_masks = next(iter(loader))
    images = images.to(device)
    true_masks = true_masks.to(device)
    with torch.no_grad():
        # Get model predictions and reshape to the mask dimensions
        pred = predict(images)
    # Reshape predictions to match the true mask shape
    pred = pred.reshape(true_masks.size()).cpu().numpy()
    true_masks = true_masks.cpu().numpy()
    images = images.cpu().numpy()
    
    fig, axes = plt.subplots(3, num_images, figsize=(15, 10))
    for i in range(num_images):
         # Show input image
         axes[0, i].imshow(images[i].transpose(1, 2, 0), cmap='gray')
         axes[0, i].set_title("Input Image")
         axes[0, i].axis("off")
         # Show true mask (using grayscale for clarity)
         axes[1, i].imshow(true_masks[i].transpose(1, 2, 0), cmap='gray')
         axes[1, i].set_title("True Mask")
         axes[1, i].axis("off")
         # Show predicted mask (using grayscale for clarity)
         axes[2, i].imshow(pred[i].transpose(1, 2, 0), cmap='gray')
         axes[2, i].set_title("Predicted Mask")
         axes[2, i].axis("off")
    plt.tight_layout()
    plt.show()


visualize_predictions(vae, test_loader)
