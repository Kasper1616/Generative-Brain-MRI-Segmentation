# %% [markdown]
# # Generative Medical Image Segmentation

# %%
# --- Import Libraries ---
import matplotlib.pyplot as plt
import pyro
import pyro.distributions as dist
import seaborn as sns
import torch
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam
from torch import nn
import sys
import os

sys.path.append(os.path.join(os.getcwd(), ".."))

from scripts.data import get_loaders
from scripts.funcs import run_model

# Define device
device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"


# --- Set Plot Style ---
sns.set_style("dark")
plt.style.use("dark_background")


# --- Define Parameters ---
BATCH_SIZE = 64
IMG_SIZE = 64
NUM_WORKERS = 0

# %% [markdown]
# ### Define Dataloaders

# %%
train_loader, test_loader = get_loaders("../data/", batch_size=BATCH_SIZE, img_size=IMG_SIZE, num_workers=NUM_WORKERS)

# %% [markdown]
# ### Define Model

# %%
# --- Define Encoder ---
class Encoder(nn.Module):
    def __init__(self, z_dim, input_dim = IMG_SIZE*IMG_SIZE*3):
        self.input_dim = input_dim
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.Softplus(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.Softplus(),
            nn.AdaptiveAvgPool2d((1,1)),
            nn.Flatten(),
            nn.Linear(32, 2 * z_dim))

    def forward(self, x):
        # Compute the hidden units
        hidden = self.conv(x)
        # then return a mean vector and a (positive) square root covariance
        mu, log_var = hidden.chunk(2, dim=-1)
        return mu, torch.exp(log_var)
       
    
# --- Define Decoder ---
class Decoder(nn.Module):
    def __init__(self, xz_dim, output_dim):
        super().__init__()
        self.output_dim = output_dim
        self.fc = nn.Linear(xz_dim, 64)
        self.conv = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=IMG_SIZE, stride=IMG_SIZE),
            nn.Softplus(),
            nn.Conv2d(32, 1, kernel_size=3, padding=1),
            nn.Sigmoid()
        )

    def forward(self, z):
        return self.conv(self.fc(z).view(-1, 64, 1, 1))

# %% [markdown]
# ### Define VAE

# %%
# --- Define VAE ---
class CVAE(nn.Module):
    def __init__(self, z_dim=64, hidden_dim=248, input_dim=IMG_SIZE*IMG_SIZE*3):
        self.input_dim = input_dim
        self.output_dim = IMG_SIZE*IMG_SIZE
        super().__init__()

        # Define the encoder and decoder networks
        self.encoder = Encoder(z_dim, self.input_dim)
        self.decoder = Decoder(z_dim+self.input_dim, self.output_dim)
        self.z_dim = z_dim

    # Define the model p(y|z)p(z)
    def model(self, x, y=None):
        pyro.module("decoder", self.decoder)
        batch_size = x.size(0)
        with pyro.plate("data", batch_size):

            # setup hyperparameters for prior p(z)
            z_loc = torch.zeros(x.shape[0], self.z_dim, dtype=x.dtype, device=device)
            z_scale = torch.ones(x.shape[0], self.z_dim, dtype=x.dtype, device=device)

            # sample from prior
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))


            # flatten the image x
            x_flatten = x.reshape(-1, self.input_dim)

            # condact the image x to the latent variable z
            xz = torch.cat([z, x_flatten], dim=1)

            # decode the latent code z
            yhat = self.decoder.forward(xz).view(batch_size, -1)

            if y is not None:
                pyro.sample("obs", 
                        dist.Bernoulli(yhat, validate_args=False).to_event(1), 
                        obs=y.reshape(-1, self.output_dim),)
                
            else:
                pyro.deterministic('obs', yhat.detach())

            return yhat

    # Define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x, y=None):
        # use the encoder to get the parameters used to define q(z|x)
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):

            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)

            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
# --- Training the CVAE ---
num_epochs = 500
test_frequency = 10
lr = 1e-3

vae = CVAE(z_dim=64, hidden_dim=248, input_dim=IMG_SIZE*IMG_SIZE*3)

# setup the optimizer
optimizer = Adam({"lr": lr})
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

vae = run_model(vae, svi, train_loader, test_loader, num_epochs=num_epochs, test_frequency=test_frequency, lr=lr, device=device)
# Out:
# [Epoch 1]
# Mean train loss: 521.3854
# Mean test loss: 197.1577
#
# [Epoch 2]
# Mean train loss: 196.2061
#
# [Epoch 3]
# Mean train loss: 169.0207
#
# [Epoch 4]
# Mean train loss: 148.5603
#
# [Epoch 5]
# Mean train loss: 132.5090
#
# [Epoch 6]
# Mean train loss: 119.5343
#
# [Epoch 7]
# Mean train loss: 109.8889
#
# [Epoch 8]
# Mean train loss: 101.4369
#
# [Epoch 9]
# Mean train loss: 95.1872
#
# [Epoch 10]
# Mean train loss: 92.1118
#
# [Epoch 11]
# Mean train loss: 83.8170
# Mean test loss: 81.4819
#
# [Epoch 12]
# Mean train loss: 79.4041
#
# [Epoch 13]
# Mean train loss: 75.5211
#
# [Epoch 14]
# Mean train loss: 67.8882
#
# [Epoch 15]
# Mean train loss: 63.2870
#
# [Epoch 16]
# Mean train loss: 60.4204
#
# [Epoch 17]
# Mean train loss: 57.0397
#
# [Epoch 18]
# Mean train loss: 55.8644
#
# [Epoch 19]
# Mean train loss: 53.1879
#
# [Epoch 20]
# Mean train loss: 52.4144
#
# [Epoch 21]
# Mean train loss: 50.7362
# Mean test loss: 60.3135
#
# [Epoch 22]
# Mean train loss: 48.4790
#
# [Epoch 23]
# Mean train loss: 50.2160
#
# [Epoch 24]
# Mean train loss: 46.6715
#
# [Epoch 25]
# Mean train loss: 45.0415
#
# [Epoch 26]
# Mean train loss: 45.0798
#
# [Epoch 27]
# Mean train loss: 42.8594
#
# [Epoch 28]
# Mean train loss: 42.5278
#
# [Epoch 29]
# Mean train loss: 41.5228
#
# [Epoch 30]
# Mean train loss: 39.8333
#
# [Epoch 31]
# Mean train loss: 38.7883
# Mean test loss: 53.1989
#
# [Epoch 32]
# Mean train loss: 37.9702
#
# [Epoch 33]
# Mean train loss: 38.4762
#
# [Epoch 34]
# Mean train loss: 36.3351
#
# [Epoch 35]
# Mean train loss: 37.4275
#
# [Epoch 36]
# Mean train loss: 35.6960
#
# [Epoch 37]
# Mean train loss: 34.7554
#
# [Epoch 38]
# Mean train loss: 33.5307
#
# [Epoch 39]
# Mean train loss: 33.6010
#
# [Epoch 40]
# Mean train loss: 32.8420
#
# [Epoch 41]
# Mean train loss: 32.1198
# Mean test loss: 50.7734
#
# [Epoch 42]
# Mean train loss: 33.9445
#
# [Epoch 43]
# Mean train loss: 33.1829
#
# [Epoch 44]
# Mean train loss: 32.9337
#
# [Epoch 45]
# Mean train loss: 31.1276
#
# [Epoch 46]
# Mean train loss: 30.8355
#
# [Epoch 47]
# Mean train loss: 29.8147
#
# [Epoch 48]
# Mean train loss: 31.4335
#
# [Epoch 49]
# Mean train loss: 29.6486
#
# [Epoch 50]
# Mean train loss: 28.3859
#
# [Epoch 51]
# Mean train loss: 29.6313
# Mean test loss: 53.0069
#
# [Epoch 52]
# Mean train loss: 29.7640
#
# [Epoch 53]
# Mean train loss: 27.2811
#
# [Epoch 54]
# Mean train loss: 27.4264
#
# [Epoch 55]
# Mean train loss: 26.8560
#
# [Epoch 56]
# Mean train loss: 26.3874
#
# [Epoch 57]
# Mean train loss: 27.0042
#
# [Epoch 58]
# Mean train loss: 26.0546
#
# [Epoch 59]
# Mean train loss: 26.1438
#
# [Epoch 60]
# Mean train loss: 26.7556
#
# [Epoch 61]
# Mean train loss: 27.4993
# Mean test loss: 46.5937
#
# [Epoch 62]
# Mean train loss: 27.3000
#
# [Epoch 63]
# Mean train loss: 25.8957
#
# [Epoch 64]
# Mean train loss: 24.6194
#
# [Epoch 65]
# Mean train loss: 24.7235
#
# [Epoch 66]
# Mean train loss: 25.0793
#
# [Epoch 67]
# Mean train loss: 24.8604
#
# [Epoch 68]
# Mean train loss: 24.0046
#
# [Epoch 69]
# Mean train loss: 23.3710
#
# [Epoch 70]
# Mean train loss: 22.8235
#
# [Epoch 71]
# Mean train loss: 22.5832
# Mean test loss: 46.1552
#
# [Epoch 72]
# Mean train loss: 22.5614
#
# [Epoch 73]
# Mean train loss: 22.2597
#
# [Epoch 74]
# Mean train loss: 22.3701
#
# [Epoch 75]
# Mean train loss: 23.2438
#
# [Epoch 76]
# Mean train loss: 22.4396
#
# [Epoch 77]
# Mean train loss: 22.4962
#
# [Epoch 78]
# Mean train loss: 21.6751
#
# [Epoch 79]
# Mean train loss: 21.8825
#
# [Epoch 80]
# Mean train loss: 21.9669
#
# [Epoch 81]
# Mean train loss: 22.5305
# Mean test loss: 52.0607
#
# [Epoch 82]
# Mean train loss: 24.0016
#
# [Epoch 83]
# Mean train loss: 22.7975
#
# [Epoch 84]
# Mean train loss: 23.1452
#
# [Epoch 85]
# Mean train loss: 20.9243
#
# [Epoch 86]
# Mean train loss: 20.9886
#
# [Epoch 87]
# Mean train loss: 21.4394
#
# [Epoch 88]
# Mean train loss: 21.5669
#
# [Epoch 89]
# Mean train loss: 20.9256
#
# [Epoch 90]
# Mean train loss: 20.1971
#
# [Epoch 91]
# Mean train loss: 19.9678
# Mean test loss: 49.6113
#
# [Epoch 92]
# Mean train loss: 20.2889
#
# [Epoch 93]
# Mean train loss: 20.1026
#
# [Epoch 94]
# Mean train loss: 20.2846
#
# [Epoch 95]
# Mean train loss: 19.9222
#
# [Epoch 96]
# Mean train loss: 20.0733
#
# [Epoch 97]
# Mean train loss: 19.9161
#
# [Epoch 98]
# Mean train loss: 20.9362
#
# [Epoch 99]
# Mean train loss: 20.2212
#
# [Epoch 100]
# Mean train loss: 19.4425
#
# [Epoch 101]
# Mean train loss: 19.1405
# Mean test loss: 46.4700
#
# [Epoch 102]
# Mean train loss: 18.9185
#
# [Epoch 103]
# Mean train loss: 18.7073
#
# [Epoch 104]
# Mean train loss: 18.8066
#
# [Epoch 105]
# Mean train loss: 18.8373
#
# [Epoch 106]
# Mean train loss: 18.9027
#
# [Epoch 107]
# Mean train loss: 18.9488
#
# [Epoch 108]
# Mean train loss: 18.8087
#
# [Epoch 109]
# Mean train loss: 18.8751
#
# [Epoch 110]
# Mean train loss: 18.5728
#
# [Epoch 111]
# Mean train loss: 21.6750
# Mean test loss: 45.6693
#
# [Epoch 112]
# Mean train loss: 19.0246
#
# [Epoch 113]
# Mean train loss: 19.5324
#
# [Epoch 114]
# Mean train loss: 18.5114
#
# [Epoch 115]
# Mean train loss: 18.2588
#
# [Epoch 116]
# Mean train loss: 18.0209
#
# [Epoch 117]
# Mean train loss: 17.6821
#
# [Epoch 118]
# Mean train loss: 17.4185
#
# [Epoch 119]
# Mean train loss: 18.4129
#
# [Epoch 120]
# Mean train loss: 17.9468
#
# [Epoch 121]
# Mean train loss: 17.8145
# Mean test loss: 48.8273
#
# [Epoch 122]
# Mean train loss: 17.8290
#
# [Epoch 123]
# Mean train loss: 17.8087
#
# [Epoch 124]
# Mean train loss: 17.7447
#
# [Epoch 125]
# Mean train loss: 17.8007
#
# [Epoch 126]
# Mean train loss: 17.7102
#
# [Epoch 127]
# Mean train loss: 18.3109
#
# [Epoch 128]
# Mean train loss: 18.9761
#
# [Epoch 129]
# Mean train loss: 17.6422
#
# [Epoch 130]
# Mean train loss: 17.7933
#
# [Epoch 131]
# Mean train loss: 17.9991
# Mean test loss: 47.1188
#
# [Epoch 132]
# Mean train loss: 17.4260
#
# [Epoch 133]
# Mean train loss: 17.4388
#
# [Epoch 134]
# Mean train loss: 17.7574
#
# [Epoch 135]
# Mean train loss: 17.2713
#
# [Epoch 136]
# Mean train loss: 17.0048
#
# [Epoch 137]
# Mean train loss: 16.6902
#
# [Epoch 138]
# Mean train loss: 16.7828
#
# [Epoch 139]
# Mean train loss: 17.4408
#
# [Epoch 140]
# Mean train loss: 17.4849
#
# [Epoch 141]
# Mean train loss: 17.1530
# Mean test loss: 48.4757
#
# [Epoch 142]
# Mean train loss: 17.2060
#
# [Epoch 143]
# Mean train loss: 16.8571
#
# [Epoch 144]
# Mean train loss: 16.5662
#
# [Epoch 145]
# Mean train loss: 16.3807
#
# [Epoch 146]
# Mean train loss: 16.3346
#
# [Epoch 147]
# Mean train loss: 16.3128
#
# [Epoch 148]
# Mean train loss: 16.2765
#
# [Epoch 149]
# Mean train loss: 17.7098
#
# [Epoch 150]
# Mean train loss: 18.0028
#
# [Epoch 151]
# Mean train loss: 17.3423
# Mean test loss: 46.9993
#
# [Epoch 152]
# Mean train loss: 16.8305
#
# [Epoch 153]
# Mean train loss: 16.8776
#
# [Epoch 154]
# Mean train loss: 16.5607
#
# [Epoch 155]
# Mean train loss: 17.2507
#
# [Epoch 156]
# Mean train loss: 17.1381
#
# [Epoch 157]
# Mean train loss: 16.5341
#
# [Epoch 158]
# Mean train loss: 18.7104
#
# [Epoch 159]
# Mean train loss: 19.5822
#
# [Epoch 160]
# Mean train loss: 18.6529
#
# [Epoch 161]
# Mean train loss: 17.3614
# Mean test loss: 46.7796
#
# [Epoch 162]
# Mean train loss: 16.3764
#
# [Epoch 163]
# Mean train loss: 16.1490
#
# [Epoch 164]
# Mean train loss: 16.3326
#
# [Epoch 165]
# Mean train loss: 16.5974
#
# [Epoch 166]
# Mean train loss: 15.9815
#
# [Epoch 167]
# Mean train loss: 15.7544
#
# [Epoch 168]
# Mean train loss: 15.7037
#
# [Epoch 169]
# Mean train loss: 17.0449
#
# [Epoch 170]
# Mean train loss: 16.7876
#
# [Epoch 171]
# Mean train loss: 16.1032
# Mean test loss: 47.8618
#
# [Epoch 172]
# Mean train loss: 15.9976
#
# [Epoch 173]
# Mean train loss: 15.8668
#
# [Epoch 174]
# Mean train loss: 16.2254
#
# [Epoch 175]
# Mean train loss: 16.7951
#
# [Epoch 176]
# Mean train loss: 16.1833
#
# [Epoch 177]
# Mean train loss: 15.7079
#
# [Epoch 178]
# Mean train loss: 15.6917
#
# [Epoch 179]
# Mean train loss: 15.6638
#
# [Epoch 180]
# Mean train loss: 15.6818
#
# [Epoch 181]
# Mean train loss: 15.7900
# Mean test loss: 47.7683
#
# [Epoch 182]
# Mean train loss: 15.5683
#
# [Epoch 183]
# Mean train loss: 15.8097
#
# [Epoch 184]
# Mean train loss: 16.2047
#
# [Epoch 185]
# Mean train loss: 16.1996
#
# [Epoch 186]
# Mean train loss: 16.4037
#
# [Epoch 187]
# Mean train loss: 16.3275
#
# [Epoch 188]
# Mean train loss: 15.8688
#
# [Epoch 189]
# Mean train loss: 15.5895
#
# [Epoch 190]
# Mean train loss: 15.3364
#
# [Epoch 191]
# Mean train loss: 15.9490
# Mean test loss: 46.8565
#
# [Epoch 192]
# Mean train loss: 16.0295
#
# [Epoch 193]
# Mean train loss: 16.0918
#
# [Epoch 194]
# Mean train loss: 15.8793
#
# [Epoch 195]
# Mean train loss: 15.9195
#
# [Epoch 196]
# Mean train loss: 15.7879
#
# [Epoch 197]
# Mean train loss: 15.5155
#
# [Epoch 198]
# Mean train loss: 15.7697
#
# [Epoch 199]
# Mean train loss: 15.5304
#
# [Epoch 200]
# Mean train loss: 15.4646
#
# [Epoch 201]
# Mean train loss: 15.9666
# Mean test loss: 48.2805
#
# [Epoch 202]
# Mean train loss: 15.6592
#
# [Epoch 203]
# Mean train loss: 15.6796
#
# [Epoch 204]
# Mean train loss: 16.1298
#
# [Epoch 205]
# Mean train loss: 19.2708
#
# [Epoch 206]
# Mean train loss: 18.9399
#
# [Epoch 207]
# Mean train loss: 18.5799
#
# [Epoch 208]
# Mean train loss: 16.0152
#
# [Epoch 209]
# Mean train loss: 15.2246
#
# [Epoch 210]
# Mean train loss: 15.0536
#
# [Epoch 211]
# Mean train loss: 14.9187
# Mean test loss: 45.9622
#
# [Epoch 212]
# Mean train loss: 14.9670
#
# [Epoch 213]
# Mean train loss: 14.8896
#
# [Epoch 214]
# Mean train loss: 14.7964
#
# [Epoch 215]
# Mean train loss: 14.9174
#
# [Epoch 216]
# Mean train loss: 15.0161
#
# [Epoch 217]
# Mean train loss: 14.9966
#
# [Epoch 218]
# Mean train loss: 14.9885
#
# [Epoch 219]
# Mean train loss: 14.9261
#
# [Epoch 220]
# Mean train loss: 14.9756
#
# [Epoch 221]
# Mean train loss: 15.1250
# Mean test loss: 49.0899
#
# [Epoch 222]
# Mean train loss: 15.4266
#
# [Epoch 223]
# Mean train loss: 15.8574
#
# [Epoch 224]
# Mean train loss: 16.4332
#
# [Epoch 225]
# Mean train loss: 16.2021
#
# [Epoch 226]
# Mean train loss: 15.5546
#
# [Epoch 227]
# Mean train loss: 15.2480
#
# [Epoch 228]
# Mean train loss: 15.1725
#
# [Epoch 229]
# Mean train loss: 15.0606
#
# [Epoch 230]
# Mean train loss: 15.0803
#
# [Epoch 231]
# Mean train loss: 15.0420
# Mean test loss: 48.0873
#
# [Epoch 232]
# Mean train loss: 15.0754
#
# [Epoch 233]
# Mean train loss: 15.1173
#
# [Epoch 234]
# Mean train loss: 15.5453
#
# [Epoch 235]
# Mean train loss: 15.3793
#
# [Epoch 236]
# Mean train loss: 15.9079
#
# [Epoch 237]
# Mean train loss: 16.2295
#
# [Epoch 238]
# Mean train loss: 15.5575
#
# [Epoch 239]
# Mean train loss: 15.2641
#
# [Epoch 240]
# Mean train loss: 15.1183
#
# [Epoch 241]
# Mean train loss: 14.8474
# Mean test loss: 48.2239
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 12
#       9 optimizer = Adam({"lr": lr})
#      10 svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())
# ---> 12 vae = run_model(vae, svi, train_loader, test_loader, num_epochs=num_epochs, test_frequency=test_frequency, lr=lr, device=device)
#
# File ~/Documents/Generative_BrainCancer_Segmentation/models/../scripts/funcs.py:53, in run_model(vae, svi, train_loader, test_loader, num_epochs, test_frequency, lr, device)
#      51 # training loop
#      52 for epoch in range(num_epochs):
# ---> 53     total_epoch_loss_train = train(svi, train_loader, device)
#      54     train_elbo.append(-total_epoch_loss_train)
#      55     print(f"[Epoch {epoch+1}]")
#
# File ~/Documents/Generative_BrainCancer_Segmentation/models/../scripts/funcs.py:13, in train(svi, train_loader, device)
#       9 def train(svi, train_loader, device):
#      10     # initialize loss accumulator
#      11     epoch_loss = 0.
# ---> 13     for img, mask in train_loader:
#      14
#      15         # move data to device
#      16         img = img.to(device)
#      17         mask = mask.to(device)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MBML/lib/python3.12/site-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MBML/lib/python3.12/site-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/MBML/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Documents/Generative_BrainCancer_Segmentation/models/../scripts/data.py:25, in MRIDataset.__getitem__(self, idx)
#      22 mask_path = self.df.loc[idx, "mask_path"]
#      24 img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
# ---> 25 mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
#      27 img = Image.fromarray(img)
#      28 mask = Image.fromarray(mask).convert("L")
#
# KeyboardInterrupt:

# %%
def visualize_predictions(model, loader, num_images=5):
    model.eval()
    images, true_masks = next(iter(loader))
    images = images.to(device)
    true_masks = true_masks.to(device)
    with torch.no_grad():
        # Get model predictions and reshape to the mask dimensions
        pred = model.model(images, None)
    # Reshape predictions to match the true mask shape
    pred = pred.reshape(true_masks.size()).cpu().numpy()
    true_masks = true_masks.cpu().numpy()
    images = images.cpu().numpy()
    
    fig, axes = plt.subplots(3, num_images, figsize=(15, 10))
    for i in range(num_images):
         # Show input image
         axes[0, i].imshow(images[i].transpose(1, 2, 0))
         axes[0, i].set_title("Input Image")
         axes[0, i].axis("off")
         # Show true mask (using grayscale for clarity)
         axes[1, i].imshow(true_masks[i].transpose(1, 2, 0), cmap='gray')
         axes[1, i].set_title("True Mask")
         axes[1, i].axis("off")
         # Show predicted mask (using grayscale for clarity)
         axes[2, i].imshow(pred[i].transpose(1, 2, 0), cmap='gray')
         axes[2, i].set_title("Predicted Mask")
         axes[2, i].axis("off")
    plt.tight_layout()
    plt.show()


visualize_predictions(vae, test_loader)
